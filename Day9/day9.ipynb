# %%
from bs4 import BeautifulSoup
with open("index.html",'r') as f:
    soup = BeautifulSoup(f,"html.parser")
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Document
#   </title>
#  </head>
#  <body>
#   <h1>
#    This is my site
#   </h1>
#   <h2>
#    More in this
#   </h2>
#   <a href="https://www.google.com" target="_blank">
#    Google
#   </a>
#  </body>
# </html>

# %%
data = soup.h1
print(data)
# Out:
# <h1>This is my site</h1>

# %%
print("hello")
# Out:
# hello

# %%
import requests
url = "https://ekantipur.com"
response = requests.get(url)
if response.status_code == 200:
    data = response.text
    soup = BeautifulSoup(data, 'html.parser')
    print(soup.prettify())
else:
    print(f'Response {response.status_code}')
# Out:
# <!DOCTYPE html>
# <html lang="ne">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Kantipur Daily is Nepal's no 1 Nepali news portal and Kantipur Daily's official website. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more." name="description"/>
#   <meta content="Nepal News, Online News from Nepal, Nepali News, Political, Science, Social, Sport, Ecomony, Business,Entertainment, Nepali Movie, Songs, Nepali Model, Actor,Audio, Video, Interview, Nepali Filmi News, Poems, Business news, Views, Reviews" name="keyword"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Nepali" name="language"/>
#   <meta content="" name="reply-to"/>
#   <meta content="1 day" name="revisit-after"/>
# ...

# %%
news = soup.find_all("h2")
# print(news)
for val in news:
    print(val.text)
# Out:
# धनगढीका नयाँ उम्मेदवारसँग मतदाताका पुरानै माग
# सुन र अमेरिकी डलरको मूल्य हरेक दिन नयाँ उचाइमा, किन ?
# समग्रमा ३ लाख ३७ हजार सुरक्षाकर्मी परिचालन गरिँदै
# रोकियो नेपालको यात्रा
# बागलुङका ‘ब्रान्ड’ चित्रबहादुर
# प्रमुख दलहरूले लोपोन्मुख समुदायका उम्मेदवार रोजेनन्, अन्य दलबाट ३ जना
# लगानी प्रतिबद्धता ५२ प्रतिशतले बढ्यो
# Auto Life
# राइड सेयरिङ कम्पनी इन्ड्राइभले चालकलाई सुरक्षा तालिम दियो
# गण्डकी, कर्णाली र सुदूरपश्चिमका उच्च पहाडी भूभागमा आंशिक वर्षाको सम्भावना
# गैंडाको आक्रमणबाट घाइते अशोकको उपचारका क्रममा निधन
# काठमाडौंस्थित भारतीय दूतावासमा गणतन्त्र दिवस मनाइयो
# निर्वाचनमा कुनै पनि सुरक्षा कमजोरी सह्य हुँदैन : महानिरीक्षक अर्याल
# सर्वोच्च अदालतमा विचाराधीन संसद् विघटनको मुद्दामा लिखित जवाफ पेस भए, कहिले हुन्छ सुनुवाइ ?
# घुन्साका मतदाता फागुन दोस्रो साता गाउँ फर्किने अपेक्षा
# आचारसंहिता उल्लघंन आरोपमा एमाले उम्मेदवार राईलाई मुख्य निर्वाचन अधिकृतको कार्यालयले सचेत गरायो
# पाथीभरामा केवलकार निर्माण रोक्न माग गर्दै धनकुटामा विरोध
# ...

# %%
import pandas as pd
newss = soup.find_all("h2")
final_data = []
for val in newss:
    text_data = val.text
    link_data = val.a 
    if link_data:
        link = link_data.get("href")
    if len(text_data) > 20:
        final_data.append({
            "headline":text_data,
            "Link":link
        })
df = pd.DataFrame(final_data)
df.to_csv("neww.csv",index=False)

# %%
import pandas as pd
import random
num = []
name = ["hari","Ram","Sita","Gita"]
for i in range(1,100000):
    num.append({
        "roll_no" : i,
        "Name" : name[random.randint(0,3)]
    })
df = pd.DataFrame(num)
df.to_csv("num.csv",index=False)

# for chunks in pd.read_csv("num.csv",chunksize = 1000):

# %%
import pandas as pd
data = {
    "Name" : ["Ram","Shyam","Bishnu","Braha","Krishna","Laxmi"],
    "Salary" : [1000,230,405,2005,604,999]
}
df = pd.DataFrame(data)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Salary  6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes
# None

# %%
df["Name"].unique
df['Gender'] = df["Name"].apply(lambda x : "Female" if x == "Laxmi" else "Male")
df.head()
# Out:
#       Name  Salary Gender
# 0      Ram    1000   Male
# 1    Shyam     230   Male
# 2   Bishnu     405   Male
# 3    Braha    2005   Male
# 4  Krishna     604   Male

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
df.plot.bar(x="Name",y="Salary")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.title("Name vs Salary")
# Out:
# Text(0.5, 1.0, 'Name vs Salary')

# %%
df_A = pd.DataFrame({
    "Roll" : [1,2,3],
    "Name":["Ram","Shyam","Hari"]
})
df_B = pd.DataFrame({
    "Roll":[1,2,4],
    "Percentage":[60.0,70.0,80.0]
})

inner_merge = pd.merge(df_A,df_B,on="Roll",how="inner")
outer_merge = pd.merge(df_A,df_B,on="Roll",how="outer")
print(inner_merge)
print(outer_merge)
# Out:
#    Roll   Name  Percentage
# 0     1    Ram        60.0
# 1     2  Shyam        70.0
#    Roll   Name  Percentage
# 0     1    Ram        60.0
# 1     2  Shyam        70.0
# 2     3   Hari         NaN
# 3     4    NaN        80.0
