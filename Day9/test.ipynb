# %%
import requests
from bs4 import BeautifulSoup
url = "https://x.naasasecurities.com.np/Chart?Scrip=BANDIPUR"
response = requests.get(url)
if response.status_code == 200:
    data = response.text
    soup = BeautifulSoup(data, 'html.parser')
    print(soup.prettify())
else:
    print(f'Response {response.status_code}')
# Out:
# <!DOCTYPE html>
# <html class="login-pf">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="noindex, nofollow" name="robots"/>
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport">
#     <title>
#      Login
#     </title>
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.1/css/all.min.css" rel="stylesheet"/>
#     <link href="/resources/ujpuv/login/naasaX-page/img/favicon.ico" rel="icon"/>
#     <!-- Your custom CSS -->
#     <link href="/resources/ujpuv/login/naasaX-page/css/styles.css" rel="stylesheet"/>
#     <!-- Optional: Include Keycloak's default styles if needed -->
#     <link href="/resources/ujpuv/common/keycloak/node_modules/patternfly/dist/css/patternfly.css" rel="stylesheet"/>
# ...

# %%
news = soup.find_all("div")
news
# Out:
# [<div id="main-body">
#  <div class="header_nav">
#  <div class="navbar">
#  <div class="menu-item">
#  <span class="nav-items">Products <i class="fa-solid fa-angle-down"></i></span>
#  <div class="dropdown">
#  <h3>Products</h3>
#  <div class="dropdown_items">
#  <div class="dropdown_item">
#  <a href="https://naasasecurities.com.np" style="text-decoration: none; color: inherit;" target="_blank">
#  <img alt="Naasa" src="/resources/ujpuv/login/naasaX-page/img/navbar/naasa.svg"/>
#  </a>
#  <a href="https://naasasecurities.com.np" style="text-decoration: none; color: inherit;" target="_blank">
#  <div class="heading">Naasa Securities</div>
#  <div class="desc">A Broker Company</div>
#  </a>
#  </div>
#  <div class="dropdown_item">
#  <a href="https://newkyc.naasasecurities.com.np" style="text-decoration: none; color: inherit;" target="_blank">
#  <img alt="Naasa" src="/resources/ujpuv/login/naasaX-page/img/navbar/naasa.svg"/>
#  </a>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# Make sure you have chromedriver installed
service = Service(r'E:\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe')
driver = webdriver.Chrome(service=service)

try:
    driver.get("https://x.naasasecurities.com.np/Chart?Scrip=BANDIPUR")
    time.sleep(5)  # wait for chart to render
    
    # Grab the chart element
    chart = driver.find_element(By.CLASS_NAME, "highcharts-container")
    # print(chart.text)
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[23], line 15
#      12     time.sleep(5)  # wait for chart to render
#      14     # Grab the chart element
# ---> 15     chart = driver.find_element(By.CLASS_NAME, "highcharts-container")
#      16     # print(chart.text)
#      17 finally:
#      18     driver.quit()
#
# File e:\c_drive_desktop\Advance Python\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:802, in WebDriver.find_element(self, by, value)
#     799         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     800     return elements[0]
# --> 802 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File e:\c_drive_desktop\Advance Python\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:432, in WebDriver.execute(self, driver_command, params)
# ...
